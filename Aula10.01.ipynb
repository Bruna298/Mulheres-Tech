# %%
import pandas as pd

# %%
#Demonstração de um pedaço do pipeline realizado até agora nas aulas:

#pré-processamento
import pandas as pd

dados=pd.read_csv('weight_change_dataset.csv')
dados=dados.dropna()
display(dados.describe())

#processamento
peso_inicial=dados.groupby('Current Weight (lbs)').sum()


#exibição/apresentação
peso_inicial
# Out:
#        Participant ID         Age  Current Weight (lbs)  BMR (Calories)  \
# count      100.000000  100.000000            100.000000      100.000000
# mean        50.500000   37.910000            171.533000     2518.206000
# std         29.011492   12.219454             30.333856      364.431221
# min          1.000000   18.000000            100.000000     1566.500000
# 25%         25.750000   26.750000            153.650000     2255.050000
# 50%         50.500000   38.000000            172.150000     2519.500000
# 75%         75.250000   46.250000            192.475000     2805.975000
# max        100.000000   59.000000            238.200000     3390.800000
#
#        Daily Calories Consumed  Daily Caloric Surplus/Deficit  \
# count               100.000000                     100.000000
# mean               3518.292000                    1000.091000
# std                 513.313097                     371.560827
# min                2030.900000                      82.500000
# ...

# %%
pip install polars
# Out:
# ...
#      ---------------------------------------- 32.8/32.8 MB 8.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#IMPORTANTE: utilize os dados de 2 meses para evitar a sobrecarga do programa!

import pandas as pd
import time

arquivo1=pd.read_csv("202410_NovoBolsaFamilia.csv", sep=";", encoding="latin-1") #caminhos dos arquivos
arquivo2=pd.read_csv("202411_NovoBolsaFamilia.csv", sep=";", encoding="latin-1")

inicio_tempo=time.time() #marcação do tempo de processamento
df_pandas=pd.concat([arquivo1,arquivo2])

display(df_pandas.head())

print("Tempo de execução com Pandas:", time.time() - inicio_tempo, "segundos")
# Out:
#    MÊS COMPETÊNCIA  MÊS REFERÊNCIA  UF  CÓDIGO MUNICÍPIO SIAFI NOME MUNICÍPIO  \
# 0           202410          202310  CE                    1441     JAGUARUANA
# 1           202410          202310  CE                    1441     JAGUARUANA
# 2           202410          202310  MG                    4575       GUIDOVAL
# 3           202410          202310  PA                     493           MOJU
# 4           202410          202310  PE                    2303        AFRANIO
#
#    CPF FAVORECIDO  NIS FAVORECIDO               NOME FAVORECIDO VALOR PARCELA
# 0  ***.795.893-**    1.606232e+10  FRANCISCA CALCELENA DA SILVA        650,00
# 1  ***.210.363-**    1.289352e+10         PAULO SERGIO DA SILVA        600,00
# 2  ***.403.916-**    2.091714e+10     ANA PAULA MORAIS ROMUALDO        750,00
# 3  ***.144.702-**    1.601995e+10        DINALVA DO CARMO NEVES        300,00
# 4  ***.838.234-**    1.601252e+10            HELSON TELLES MATA        750,00
# ...
